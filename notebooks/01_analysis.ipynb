# %% [markdown]
# <a href="https://colab.research.google.com/github/bichelSood/Data-Analysis/blob/main/notebooks/01_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
news=pd.read_csv("news.csv",encoding='latin1')

# %%
print(news.columns)
# Out:
# Index(['Title', 'Date', 'Description', 'Author', 'Content', 'Keywords',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 179', 'Unnamed: 180', 'Unnamed: 181', 'Unnamed: 182',
#        'Unnamed: 183', 'Unnamed: 184', 'Unnamed: 185', 'Unnamed: 186',
#        'Unnamed: 187', 'Unnamed: 188'],
#       dtype='object', length=189)

# %%
news = news.drop(columns=['Description', 'Author', 'Content', 'Keywords',
    'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
    'Unnamed: 179', 'Unnamed: 180', 'Unnamed: 181', 'Unnamed: 182',
    'Unnamed: 183', 'Unnamed: 184', 'Unnamed: 185', 'Unnamed: 186',
    'Unnamed: 187', 'Unnamed: 188'])

# %%
news=news.iloc[:,:2]

# %%
print(news.columns)
print(news.shape)
# Out:
# Index(['Title', 'Date'], dtype='object')
# (3349, 2)

# %%
print(news.isnull().sum())
# Out:
# Title    0
# Date     0
# dtype: int64

# %%
news = news.dropna()
news = news.drop_duplicates()
news['Title'] = news['Title'].str.strip()

# %%
print(news.info())
print(news.describe())
print(news.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3348 entries, 0 to 3348
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   3348 non-null   object
#  1   Date    3348 non-null   object
# dtypes: object(2)
# memory usage: 78.5+ KB
# None
#                                                     Title        Date
# count                                                3348        3348
# unique                                               3306         174
# top     Buy Adani Ports and SEZ; target of Rs 1700: Mo...  29-07-2025
# freq                                                    3          75
#                                                Title        Date
# 0  Aurobindo Pharma, Dr Reddy's, Lupin, other pha...  08-07-2025
# 1  Bharti Airtel share price falls 1.53%; stock a...  18-07-2025
# 2  Indian Oil and Adani Gas JV plans $161 million...  09-07-2025
# 3  Cipla Shares Fall in Today's Trading Session A...  03-06-2025
# 4  Here are the sectors and stocks in focus amids...  07-02-2025

# %%
grouped_news = (news.groupby("Date")["Title"].apply(list).reset_index())

# %%
print(grouped_news.head())
# Out:
#                                                 Date  \
# 0   just some time back that you resisted going t...
# 1                                         01-04-2025
# 2                                         01-05-2025
# 3                                         01-06-2025
# 4                                         01-07-2025
#
#                                                Title
# 0    [ur. You're always in a t-shirt. Like you said]
# 1  [Indian companies gear up for nuclear expansio...
# 2  [Adani Enterprises Q4 Results: Net profit rise...
# 3  [Trade Spotlight: How should you trade CDSL, M...
# 4  [PSU bank stocks snap 5-day gaining streak ami...

# %%
grouped_news = grouped_news.iloc[1:]

# %%
print(grouped_news.head())
print(grouped_news.shape)
# Out:
#          Date                                              Title
# 1  01-04-2025  [Indian companies gear up for nuclear expansio...
# 2  01-05-2025  [Adani Enterprises Q4 Results: Net profit rise...
# 3  01-06-2025  [Trade Spotlight: How should you trade CDSL, M...
# 4  01-07-2025  [PSU bank stocks snap 5-day gaining streak ami...
# 5  01-08-2025  [ITC share price gain 1.27% in friday's tradin...
# (173, 2)

# %%
grouped_news['Date'] = pd.to_datetime(
    grouped_news['Date'],
    format='%d-%m-%Y',
    errors='coerce'
)

# %%
print(grouped_news['Date'].isnull().sum())
print(grouped_news.head())
# Out:
# 0
#         Date                                              Title
# 1 2025-04-01  [Indian companies gear up for nuclear expansio...
# 2 2025-05-01  [Adani Enterprises Q4 Results: Net profit rise...
# 3 2025-06-01  [Trade Spotlight: How should you trade CDSL, M...
# 4 2025-07-01  [PSU bank stocks snap 5-day gaining streak ami...
# 5 2025-08-01  [ITC share price gain 1.27% in friday's tradin...

# %%
stock = pd.read_csv("nifty50.csv", encoding='cp1252')

# %%
print(stock.columns)
print(stock.head())
# Out:
# Index(['ï»¿Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (â‚¹ Cr)'],
#       dtype='object')
#       ï»¿Date      Open      High       Low     Close   Shares Traded   \
# 0  29-AUG-2025  24466.70  24572.45  24404.70  24426.85       325543583
# 1  28-AUG-2025  24695.80  24702.65  24481.60  24500.90       326601486
# 2  26-AUG-2025  24899.50  24919.65  24689.60  24712.05       750473927
# 3  25-AUG-2025  24949.15  25021.55  24894.35  24967.75       213032133
# 4  22-AUG-2025  25064.15  25084.85  24859.15  24870.10       210165384
#
#    Turnover (â‚¹ Cr)
# 0           26796.69
# 1           29371.67
# 2           47068.20
# 3           19871.25
# 4           19655.78

# %%
stock.columns = [
    'date',
    'open',
    'high',
    'low',
    'close',
    'shares_traded',
    'turnover_cr'
]

# %%
stock['shares_traded'] = stock['shares_traded'].astype(float)
stock['date'] = pd.to_datetime(stock['date'], dayfirst=True, errors='coerce')
# Out:
# /tmp/ipykernel_3882/1002184138.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   stock['date'] = pd.to_datetime(stock['date'], dayfirst=True, errors='coerce')

# %%
print(stock.dtypes)
print(stock['date'].isnull().sum())
print(stock.head())
# Out:
# date             datetime64[ns]
# open                    float64
# high                    float64
# low                     float64
# close                   float64
# shares_traded           float64
# turnover_cr             float64
# dtype: object
# 0
#         date      open      high       low     close  shares_traded  \
# 0 2025-08-29  24466.70  24572.45  24404.70  24426.85    325543583.0
# 1 2025-08-28  24695.80  24702.65  24481.60  24500.90    326601486.0
# 2 2025-08-26  24899.50  24919.65  24689.60  24712.05    750473927.0
# 3 2025-08-25  24949.15  25021.55  24894.35  24967.75    213032133.0
# 4 2025-08-22  25064.15  25084.85  24859.15  24870.10    210165384.0
#
#    turnover_cr
# 0     26796.69
# 1     29371.67
# 2     47068.20
# 3     19871.25
# 4     19655.78

# %%
merged = pd.merge(stock, grouped_news, left_on='date', right_on='Date', how='inner')

# %%
print(merged.isnull().sum())
print(merged.shape)
print(merged.head())
# Out:
# date             0
# open             0
# high             0
# low              0
# close            0
# shares_traded    0
# turnover_cr      0
# Date             0
# Title            0
# dtype: int64
# (132, 9)
#         date      open      high       low     close  shares_traded  \
# 0 2025-08-21  25142.00  25153.65  25054.90  25083.75    226542052.0
# 1 2025-08-20  24965.80  25088.70  24929.70  25050.55    287054119.0
# 2 2025-08-19  24891.35  25012.65  24873.95  24980.65    252340828.0
# 3 2025-08-18  24938.20  25022.00  24852.85  24876.95    363071305.0
# 4 2025-08-14  24607.25  24673.65  24596.90  24631.30    270162203.0
#
#    turnover_cr       Date                                              Title
# 0     21865.07 2025-08-21  [Stocks to Watch Today: Clean Science, Shanti ...
# 1     25330.45 2025-08-20  [KPR Mill shares rise 2.09% in Wednesday's ses...
# 2     24781.97 2025-08-19  [Kalyan Jewellers India shares decline 2.45% a...
# 3     37637.67 2025-08-18  [BSE, HDFC AMC, MCX, other capital market stoc...
# 4     22375.44 2025-08-14  [Lux Industries Standalone June 2025 Net Sales...

# %%
print(merged.columns)
print(merged.head())
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'shares_traded', 'turnover_cr',
#        'Date', 'Title'],
#       dtype='object')
#         date      open      high       low     close  shares_traded  \
# 0 2025-08-21  25142.00  25153.65  25054.90  25083.75    226542052.0
# 1 2025-08-20  24965.80  25088.70  24929.70  25050.55    287054119.0
# 2 2025-08-19  24891.35  25012.65  24873.95  24980.65    252340828.0
# 3 2025-08-18  24938.20  25022.00  24852.85  24876.95    363071305.0
# 4 2025-08-14  24607.25  24673.65  24596.90  24631.30    270162203.0
#
#    turnover_cr       Date                                              Title
# 0     21865.07 2025-08-21  [Stocks to Watch Today: Clean Science, Shanti ...
# 1     25330.45 2025-08-20  [KPR Mill shares rise 2.09% in Wednesday's ses...
# 2     24781.97 2025-08-19  [Kalyan Jewellers India shares decline 2.45% a...
# 3     37637.67 2025-08-18  [BSE, HDFC AMC, MCX, other capital market stoc...
# 4     22375.44 2025-08-14  [Lux Industries Standalone June 2025 Net Sales...

# %%
print(merged.columns)
print(merged.head())
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'shares_traded', 'turnover_cr',
#        'Date', 'Title'],
#       dtype='object')
#         date      open      high       low     close  shares_traded  \
# 0 2025-08-21  25142.00  25153.65  25054.90  25083.75    226542052.0
# 1 2025-08-20  24965.80  25088.70  24929.70  25050.55    287054119.0
# 2 2025-08-19  24891.35  25012.65  24873.95  24980.65    252340828.0
# 3 2025-08-18  24938.20  25022.00  24852.85  24876.95    363071305.0
# 4 2025-08-14  24607.25  24673.65  24596.90  24631.30    270162203.0
#
#    turnover_cr       Date                                              Title
# 0     21865.07 2025-08-21  [Stocks to Watch Today: Clean Science, Shanti ...
# 1     25330.45 2025-08-20  [KPR Mill shares rise 2.09% in Wednesday's ses...
# 2     24781.97 2025-08-19  [Kalyan Jewellers India shares decline 2.45% a...
# 3     37637.67 2025-08-18  [BSE, HDFC AMC, MCX, other capital market stoc...
# 4     22375.44 2025-08-14  [Lux Industries Standalone June 2025 Net Sales...

# %%
merged['daily_return'] = ((merged['close'] - merged['open']) / merged['open']) * 100

merged['movement'] = merged['daily_return'].apply(lambda x: 1 if x > 0 else 0)

merged['volatility_pct'] = ((merged['high'] - merged['low']) / merged['open']) * 100

# %%
print(merged[['date', 'open', 'close', 'daily_return', 'movement', 'volatility_pct']].head())
print(merged[['daily_return', 'volatility_pct']].describe())
print(merged['movement'].value_counts())
# Out:
#         date      open     close  daily_return  movement  volatility_pct
# 0 2025-08-21  25142.00  25083.75     -0.231684         0        0.392769
# 1 2025-08-20  24965.80  25050.55      0.339464         1        0.636871
# 2 2025-08-19  24891.35  24980.65      0.358759         1        0.557222
# 3 2025-08-18  24938.20  24876.95     -0.245607         0        0.678277
# 4 2025-08-14  24607.25  24631.30      0.097735         1        0.311900
#        daily_return  volatility_pct
# count    132.000000      132.000000
# mean       0.040512        0.959785
# std        0.649097        0.443550
# min       -1.376073        0.311900
# 25%       -0.367921        0.590150
# 50%       -0.028163        0.908932
# 75%        0.399951        1.162248
# max        2.066331        2.517975
# movement
# 0    67
# 1    65
# Name: count, dtype: int64

# %%
print(merged.columns)
print(merged[['date', 'open', 'close', 'daily_return', 'movement', 'volatility_pct']].head())
print(merged['movement'].value_counts())
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'shares_traded', 'turnover_cr',
#        'Date', 'Title', 'daily_return', 'movement', 'volatility_pct'],
#       dtype='object')
#         date      open     close  daily_return  movement  volatility_pct
# 0 2025-08-21  25142.00  25083.75     -0.231684         0        0.392769
# 1 2025-08-20  24965.80  25050.55      0.339464         1        0.636871
# 2 2025-08-19  24891.35  24980.65      0.358759         1        0.557222
# 3 2025-08-18  24938.20  24876.95     -0.245607         0        0.678277
# 4 2025-08-14  24607.25  24631.30      0.097735         1        0.311900
# movement
# 0    67
# 1    65
# Name: count, dtype: int64

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from vaderSentiment) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->vaderSentiment) (2026.6.17)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
sample_text = merged['Title'].iloc[0]

print(sample_text)
print(analyzer.polarity_scores(sample_text))
# Out:
# ['Stocks to Watch Today: Clean Science, Shanti Gold, India Cements, RailTel, Jupiter Wagons, V-Guard, Fortis, Innova Captab, Poly Medicure in focus on 21 August', 'Newly-listed Shanti Gold shares rally 11% after Q1 net profit surges 174% to Rs 25 crore']
# {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.7783}

# %%
merged['sentiment_score'] = merged['Title'].apply(
    lambda text: analyzer.polarity_scores(str(text))['compound']
)

# %%
def get_sentiment_label(score):
    if score >= 0.05:
        return 'positive'
    elif score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

merged['sentiment_label'] = merged['sentiment_score'].apply(get_sentiment_label)

# %%
print(merged[['date', 'Title', 'sentiment_score', 'sentiment_label']].head())
print(merged['sentiment_label'].value_counts())
print(merged['sentiment_score'].describe())
# Out:
#         date                                              Title  \
# 0 2025-08-21  [Stocks to Watch Today: Clean Science, Shanti ...
# 1 2025-08-20  [KPR Mill shares rise 2.09% in Wednesday's ses...
# 2 2025-08-19  [Kalyan Jewellers India shares decline 2.45% a...
# 3 2025-08-18  [BSE, HDFC AMC, MCX, other capital market stoc...
# 4 2025-08-14  [Lux Industries Standalone June 2025 Net Sales...
#
#    sentiment_score sentiment_label
# 0           0.7783        positive
# 1           0.8481        positive
# 2           0.9485        positive
# 3           0.9788        positive
# 4           0.8442        positive
# sentiment_label
# positive    128
# negative      4
# Name: count, dtype: int64
# count    132.000000
# mean       0.879782
# std        0.304486
# min       -0.959000
# 25%        0.913600
# 50%        0.975500
# 75%        0.988900
# max        0.999400
# Name: sentiment_score, dtype: float64

# %%
print(type(merged['Title'].iloc[0]))
print(merged['Title'].iloc[0])
# Out:
# <class 'list'>
# ['Stocks to Watch Today: Clean Science, Shanti Gold, India Cements, RailTel, Jupiter Wagons, V-Guard, Fortis, Innova Captab, Poly Medicure in focus on 21 August', 'Newly-listed Shanti Gold shares rally 11% after Q1 net profit surges 174% to Rs 25 crore']

# %%
merged['news_count'] = merged['Title'].apply(
    lambda x: len(x) if isinstance(x, list) else 1
)

# %%
print(merged[['date', 'Title', 'news_count']].head())
print(merged['news_count'].describe())
# Out:
#         date                                              Title  news_count
# 0 2025-08-21  [Stocks to Watch Today: Clean Science, Shanti ...           2
# 1 2025-08-20  [KPR Mill shares rise 2.09% in Wednesday's ses...           4
# 2 2025-08-19  [Kalyan Jewellers India shares decline 2.45% a...           6
# 3 2025-08-18  [BSE, HDFC AMC, MCX, other capital market stoc...           7
# 4 2025-08-14  [Lux Industries Standalone June 2025 Net Sales...           4
# count    132.000000
# mean      24.719697
# std       17.663225
# min        2.000000
# 25%       12.000000
# 50%       18.000000
# 75%       34.500000
# max       75.000000
# Name: news_count, dtype: float64

# %%
merged = merged.sort_values('date').reset_index(drop=True)

# %%
merged['prev_day_sentiment'] = merged['sentiment_score'].shift(1)

# %%
merged['prev_day_sentiment'] = merged['prev_day_sentiment'].fillna(0)

# %%
print(merged[['date', 'sentiment_score', 'prev_day_sentiment', 'news_count']].head(10))
print(merged[['sentiment_score', 'prev_day_sentiment', 'news_count']].describe())
# Out:
#         date  sentiment_score  prev_day_sentiment  news_count
# 0 2025-02-07           0.6486              0.0000           8
# 1 2025-02-10           0.7003              0.6486           6
# 2 2025-02-11           0.9538              0.7003          11
# 3 2025-02-12           0.7964              0.9538          18
# 4 2025-02-13           0.9274              0.7964          13
# 5 2025-02-14           0.9313              0.9274          11
# 6 2025-02-17           0.8885              0.9313          13
# 7 2025-02-18          -0.1053              0.8885          10
# 8 2025-02-19           0.5719             -0.1053          13
# 9 2025-02-20           0.7845              0.5719          12
#        sentiment_score  prev_day_sentiment  news_count
# count       132.000000          132.000000  132.000000
# mean          0.879782            0.873886   24.719697
# std           0.304486            0.313857   17.663225
# min          -0.959000           -0.959000    2.000000
# 25%           0.913600            0.913600   12.000000
# 50%           0.975500            0.975500   18.000000
# 75%           0.988900            0.988900   34.500000
# max           0.999400            0.999400   75.000000

# %%
merged.to_csv('data/final_merged_features.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_3882/4034290001.py in <cell line: 0>()
# ----> 1 merged.to_csv('data/final_merged_features.csv', index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %%
import os

os.makedirs('data', exist_ok=True)
merged.to_csv('data/final_merged_features.csv', index=False)

# %%
from google.colab import files

files.download('data/final_merged_features.csv')
